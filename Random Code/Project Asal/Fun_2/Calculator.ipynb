# %%
import math

def norm(a,b,c):
    print("Norm :", math.sqrt(math.pow(a,2) + math.pow(b,2) + math.pow(c,2)))
    return math.sqrt(math.pow(a,2) + math.pow(b,2) + math.pow(c,2))

def vi(z1,z2,z3,normZ):
    x = float(z1)/float(normZ)
    y = float(z2)/float(normZ)
    z = float(z3)/float(normZ)
    print("vi =",round(x,3), round(y,3), round(z,3))
    return float(z1)/float(normZ), float(z2)/float(normZ), float(z3/normZ)

def Z(a1,a2,a3,v1,v2,v3):
    print("zi : ", a1 * v1 + a2 * v2 + a3 * v3)
    return a1 * v1 + a2 * v2 + a3 * v3

def main():    
    # a = 0.579
    # b = 0.575
    # c = 0.579
    # x = Z(0,0,-1,a,b,c)
    # y = Z(1,1,1,a,b,c)
    # z = Z(-0.5,0,-0.5,a,b,c)
    # print("==========")
    # n = norm(x,y,z)
    # print(round(n,3))
    # vi(x,y,z,round(n,3))

    a = 1
    b = 1
    c = 1

    for i in range(0,5):
        print("======= LOOP ", i + 1, "=========")
        x = Z(0,0,-1,a,b,c)
        y = Z(1,1,1,a,b,c)
        z = Z(-0.5,0,-0.5,a,b,c)
        print("==========")
        n = norm(x,y,z)
        print(round(n,3))
        
        a,b,c = vi(x,y,z,round(n,5))
        print("========= END ==============")
    
main()
# Out:
# ======= LOOP  1 =========
# zi :  -1
# zi :  3
# zi :  -1.0
# ...
# Norm : 3.3166247903554
# 3.317
# vi = -0.302 0.905 -0.302
# ========= END ==============
# ======= LOOP  2 =========
# zi :  0.30151178006524715
# zi :  0.30151178006524715
# zi :  0.30151178006524715
# ...
# Norm : 0.522233722153541
# 0.522
# vi = 0.577 0.577 0.577
# ========= END ==============
# ======= LOOP  3 =========
# zi :  -0.5773543842085809
# zi :  1.7320631526257426
# zi :  -0.5773543842085809
# ...
# Norm : 1.9148678634865555
# 1.915
# vi = -0.302 0.905 -0.302
# ========= END ==============
# ======= LOOP  4 =========
# zi :  0.3015110081669152
# zi :  0.30151100816691506
# zi :  0.3015110081669152
# ...
# Norm : 0.5222323851864117
# 0.522
# vi = 0.577 0.577 0.577
# ========= END ==============
# ======= LOOP  5 =========
# zi :  -0.5773529061274059
# zi :  1.7320587183822176
# zi :  -0.5773529061274059
# ...
# Norm : 1.9148629612458885
# 1.915
# vi = -0.302 0.905 -0.302
# ========= END ==============
